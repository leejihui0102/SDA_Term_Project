# %%
import pandas as pd

data = pd.read_csv("data/2022.1월_29개 통신정보.CSV", encoding = "euc-kr")
data.head(10)
# Out:
#      행정동코드  자치구  행정동  성별  연령대  총인구수  1인가구수  야간상주지 변경 미추정 인구 수  야간상주지 변경횟수 평균  \
# 0  1101053  종로구  사직동   1   20   220     68                  0            2.6
# 1  1101053  종로구  사직동   1   25   321    107                  0            2.3
# 2  1101053  종로구  사직동   1   30   351    107                  0            2.2
# 3  1101053  종로구  사직동   1   35   353    105                  0            2.0
# 4  1101053  종로구  사직동   1   40   419     79                  0            1.9
# 5  1101053  종로구  사직동   1   45   352     72                  0            1.8
# 6  1101053  종로구  사직동   1   50   323     49                  0            1.8
# 7  1101053  종로구  사직동   1   55   350     56                  0            1.7
# 8  1101053  종로구  사직동   1   60   245     41                  0            1.7
# 9  1101053  종로구  사직동   1   65   180     30                  0            1.6
#
#    야간상주지 변경횟수: 4분위수, 25%  ...  배달_브랜드 서비스 사용 미추정 인구수  배달_브랜드 서비스 사용일수  \
# ...
