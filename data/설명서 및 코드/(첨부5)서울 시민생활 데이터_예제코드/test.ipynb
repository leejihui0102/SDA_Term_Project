# %%
import pandas as pd
df = pd.read_csv('1인가구_관심집단.csv', encoding = "euc-kr")
df.head(10)
# Out:
#      행정동코드  자치구 행정동명  성별  연령대  총인구 1인가구수  커뮤니케이션이 적은 집단  평일 외출이 적은 집단  \
# 0  1101053  종로구  사직동   1   20  220    68             14             7
# 1  1101053  종로구  사직동   1   25  321   107             16            12
# 2  1101053  종로구  사직동   1   30  351   107             19            16
# 3  1101053  종로구  사직동   1   35  353   105             22            13
# 4  1101053  종로구  사직동   1   40  419    79             18             7
# 5  1101053  종로구  사직동   1   45  352    72             15            10
# 6  1101053  종로구  사직동   1   50  323    49              5             6
# 7  1101053  종로구  사직동   1   55  350    56              9             5
# 8  1101053  종로구  사직동   1   60  245    41              5             3
# 9  1101053  종로구  사직동   1   65  180    30              2             1
#
#    휴일 외출이 적은 집단  출근소요시간 및 근무시간이 많은 집단  외출이 매우 적은 집단 (전체)  외출이 매우 많은 집단  \
# 0             4                     6                  4             5
# ...
